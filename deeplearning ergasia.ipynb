# %% [markdown]
# <a href="https://colab.research.google.com/github/aivc24024/lenet-images/blob/main/deeplearning%20ergasia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# Load CIFAR-100 dataset
(cifar100_train, cifar100_test) = tf.keras.datasets.cifar100.load_data()

# Unpack the dataset
(x_train, y_train) = cifar100_train
(x_test, y_test) = cifar100_test

# %%
x_train
# Out:
# array([[[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [195, 205, 193],
#          [212, 224, 204],
#          [182, 194, 167]],
#
#         [[255, 255, 255],
#          [254, 254, 254],
#          [254, 254, 254],
#          ...,
#          [170, 176, 150],
#          [161, 168, 130],
#          [146, 154, 113]],
#
#         [[255, 255, 255],
#          [254, 254, 254],
#          [255, 255, 255],
#          ...,
#          [189, 199, 169],
#          [166, 178, 130],
#          [121, 133,  87]],
#
#         ...,
#
#         [[148, 185,  79],
#          [142, 182,  57],
#          [140, 179,  60],
#          ...,
#          [ 30,  17,   1],
#          [ 65,  62,  15],
#          [ 76,  77,  20]],
#
#         [[122, 157,  66],
#          [120, 155,  58],
#          [126, 160,  71],
#          ...,
#          [ 22,  16,   3],
#          [ 97, 112,  56],
#          [141, 161,  87]],
#
#         [[ 87, 122,  41],
# ...

# %%
train_x = x_train[:70]
train_y = y_train[:70]

test_x = x_train[70:]
test_y = y_train[70:]

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
height,width=180,180

# %%
training_batch_size=32

# %%
image_size=(height,width),
batch_size=training_batch_size

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
dnn_model = Sequential()

# %%
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50
inputs = layers.Input(shape=(32, 32, 3))  # Input shape matches CIFAR-100
x = layers.Resizing(224, 224)(inputs)  # Resize within the model
base = ResNet50(weights='imagenet', include_top=False, input_tensor=x)
base.trainable = False
x = layers.GlobalAveragePooling2D()(base.output)
x = layers.Dense(128, activation='relu')(x)
outputs = layers.Dense(100, activation='softmax')(x)

dnn_model = models.Model(inputs, outputs)

# %%
from tensorflow.python.keras.layers import Dense, Flatten

# %%
# Assuming 'imported_model' is your ResNet50 Functional model

# Instead of adding to a Sequential model, create a Functional model
from tensorflow.keras.layers import Input, Flatten, Dense
from tensorflow.keras.models import Model

inputs = imported_model.input
# Get the output of the imported_model
x = imported_model.output
x = Flatten()(x)  # Apply Flatten to the output
x = Dense(512, activation='relu')(x)
outputs = Dense(5, activation='softmax')(x)

# Create the Functional model
dnn_model = Model(inputs=inputs, outputs=outputs)

# %%
dnn_model.summary()
# Out:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 230, 230,  │          0 │ input_layer_6[0]… │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 112, 112,  │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
from tensorflow.keras.optimizers import Adam
dnn_model.compile(optimizer=Adam(0.001),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50

# Νέο μοντέλο με input resizing layer
inputs = layers.Input(shape=(32, 32, 3))
x = layers.Resizing(224, 224)(inputs)  # Resize within model
base = ResNet50(weights='imagenet', include_top=False, input_tensor=x)
base.trainable = False
x = layers.GlobalAveragePooling2D()(base.output)
x = layers.Dense(128, activation='relu')(x)
outputs = layers.Dense(100, activation='softmax')(x)

model = models.Model(inputs, outputs)

# %%
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50

# Create a new model with an input resizing layer
inputs = layers.Input(shape=(32, 32, 3))  # Input shape matches CIFAR-100
x = layers.Resizing(224, 224)(inputs)  # Resize within the model
base = ResNet50(weights='imagenet', include_top=False, input_tensor=x)
base.trainable = False
x = layers.GlobalAveragePooling2D()(base.output)
x = layers.Dense(128, activation='relu')(x)
outputs = layers.Dense(100, activation='softmax')(x)

dnn_model = models.Model(inputs, outputs)  # Assign to dnn_model

# Compile the model
dnn_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = dnn_model.fit(
    train_x, train_y,
    validation_data=(test_x, test_y),
    epochs=1
)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.0042 - loss: 5.2225
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-106-ddaa901d3677> in <cell line: 0>()
#      17
#      18 # Train the model
# ---> 19 history = dnn_model.fit(
#      20     train_x, train_y,
#      21     validation_data=(test_x, test_y),
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ...

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


# Load an image
img = mpimg.imread('/content/markos.jpg')

# Display the image
plt.imshow(img)
plt.axis('off')  # Hide axis ticks
plt.show()

# %%
import cv2
image=cv2.imread(str(img))
image_resized= cv2.resize(img, (height, width))
image=np.expand_dims(image_resized,axis=0)
print(image.shape)
# Out:
# (1, 180, 180, 3)

# %%
model_pred=dnn_model.predict(img)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-9e36699d4368> in <cell line: 0>()
# ----> 1 model_pred=dnn_model.predict(img)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     243                 if spec_dim is not None and dim is not None:
#     244                     if spec_dim != dim:
# --> 245                         raise ValueError(
# ...

# %%
image.show(image)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-115-7a797fb41685> in <cell line: 0>()
# ----> 1 image.show(image)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'show'

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(train_generator, epochs=2, validation_data=val_generator)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-4d3bf248fe26> in <cell line: 0>()
#       1 model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#       2
# ----> 3 model.fit(train_generator, epochs=2, validation_data=val_generator)
#
# NameError: name 'train_generator' is not defined

# %%
from google.colab import files
import tarfile

# Step 1: Upload the .tar.gz file
uploaded = files.upload()

# Step 2: Extract the uploaded file
filename = list(uploaded.keys())[0]  # Get the uploaded file name

# Open and extract
with tarfile.open(filename, "r:gz") as tar:
    tar.extractall()  # You can pass a path to extract to a specific directory
    tar.list()  # Optional: show the list of extracted files
# Out:
#      <input type="file" id="files-46867268-f2a6-4c6f-b7e2-8bd909db4ec7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-46867268-f2a6-4c6f-b7e2-8bd909db4ec7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import tarfile
import pickle

with tarfile.open("cifar-100-python.tar.gz", "r:gz") as tar:
    tar.extractall()

with open("cifar-100-python/train", 'rb') as f:
    data = pickle.load(f, encoding='latin1')

images = data['data']
labels = data['fine_labels']

print(images.shape)  # (50000, 3072)
# Out:
# (50000, 3072)

# %%
import numpy as np

images = images.reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)
#resnet50 waits images in format (batch, width, height, channels)

# %%
#import libraries
import pandas as pd # excel reading
import matplotlib.pyplot as plt
import sklearn # we need this for the classifiers
import numpy as np # mathematical operators
import keras # artificial neural networks (it uses tensorflow)
#import xlrd

# %%
from tensorflow.keras.datasets import cifar100
from sklearn.model_selection import train_test_split

X_train_reshaped = X_train.reshape(X_train.shape[0], -1)
X_test_reshaped = X_test.reshape(X_test.shape[0], -1)

# Now apply MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train_reshaped)
X_test_scaled = scaler.transform(X_test_reshaped)

# Load the dataset using cifar100.load_data
(X_train, y_train), (X_test, y_test) = cifar100.load_data(label_mode='fine')

y_train = to_categorical(y_train, 100)
y_test = to_categorical(y_test, 100)

print('Train set sample size:', len(X_train))
print('Test set sample size:', len(X_test))

print('Test set percentage:', len(X_test) / (len(X_train) + len(X_test)))
# Out:
# Train set sample size: 50000
# Test set sample size: 10000
# Test set percentage: 0.16666666666666666

# %%
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50

# Νέο μοντέλο με input resizing layer
inputs = layers.Input(shape=(32, 32, 3))
x = layers.Resizing(224, 224)(inputs)  # Resize within model
base = ResNet50(weights='imagenet', include_top=False, input_tensor=x)
base.trainable = False
x = layers.GlobalAveragePooling2D()(base.output)
x = layers.Dense(128, activation='relu')(x)
outputs = layers.Dense(100, activation='softmax')(x)

model = models.Model(inputs, outputs)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(train_generator, epochs=2, validation_data=val_generator)
# Out:
# Epoch 1/2
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   6/625 ━━━━━━━━━━━━━━━━━━━━ 1:12:22 7s/step - accuracy: 0.0041 - loss: 4.7386
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-4d3bf248fe26> in <cell line: 0>()
#       1 model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#       2
# ----> 3 model.fit(train_generator, epochs=2, validation_data=val_generator)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
# ...
